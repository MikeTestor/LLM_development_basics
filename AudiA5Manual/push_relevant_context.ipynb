# %%
import os
import glob
from dotenv import load_dotenv
from openai import OpenAI

# %%
from services.text_helpers import load_url_text_map

a5Manual = load_url_text_map()

# %%
print(a5Manual)
# Out:
# {'https://ownersmanual.audi.com/app/rdw/chapters?language=nl_NL': 'Kort en bondig\nWeergave en bediening\nStarten en rijden\nHulpsystemen\nInfotainment\nVerzorging en onderhoud\nZelf problemen verhelpen\nKlantinformatie', 'https://ownersmanual.audi.com/app/rdw/chapters/Qk9SRE5FVFo?language=nl_NL': 'Kort en bondig\nWeergave en bediening\nStarten en rijden\nHulpsystemen\nInfotainment\nVerzorging en onderhoud\nZelf problemen verhelpen\nKlantinformatie\nControleren en bijvullen\nWielen\nVerzorgen en schoonmaken\nBrandstof\nTanken\nSelective Catalytic Reduction (AdBlue/DEF)\nUitlaatgasreinigingssysteem\nRoetfilter\nMotorruimte\nMotorolie\nKoelsysteem\nRemvloeistof\nElektrische installatie\nAccu\nRuitensproeierinstallatie\nService-intervalindicatie\nSmart Service\nOnline Car Care\nAanwijzingen voor de bestuurder met betrekking tot de elektrische installatie', 'https://ownersmanual.audi.com/app/rdw/chapters/Qk9SRFNURUlOV0FSTlVORw?language=nl_NL': "Kort en bondig\nWeergave en bediening\nStarten en rijden\nHulpsystemen\nInfotainment\nVerzorging en onderhoud\nZelf problemen verhelpen\nKlantinformatie\nAlgemene informatie over hulpsystemen\nWaarschuwingssystemen\nRijstrookhulpsystemen\nSnelheidshulpsystemen\nGecombineerde hulpsystemen\nRem- en uitwijksystemen\nVerdere hulpsystemen\nParkeerhulpsystemen\nOndersteunende parkeersystemen\nParkeerhulpsystemen met afstandsindicatie\nAchteruitrijcamera of omgevingscamera's\nNoodremassistent achter\nAssistent voor kruisend verkeer achter\nStoeprandwaarschuwing\nManoeuvreerhulp\nInleiding\nStoeprandwaarschuwing gebruiken\nStoeprandwaarschuwing activeren en deactiveren\nAanwijzingen voor de bestuurder over de stoeprandwaarschuwing", 'https://ownersmanual.audi.com/app/rdw/chapters/QkFUVEVSSUU?language=nl_NL': "Kort en bondig\nWeergave en bediening\nStarten en rijden\nHulpsystemen\nInfotainment\nVerzorging en onderhoud\nZelf problemen verhelpen\nKlantinformatie\nControleren en bijvullen\nWielen\nVerzorgen en schoonmaken\nBrandstof\nTanken\nSelective Catalytic Reduction (AdBlue/DEF)\nUitlaatgasreinigingssysteem\nRoetfilter\nMotorruimte\nMotorolie\nKoelsysteem\nRemvloeistof\nElektrische installatie\nAccu\nRuitensproeierinstallatie\nService-intervalindicatie\nSmart Service\nOnline Car Care\nVeiligheidsaanwijzingen voor accu's\nInformatie over accu’s\n12 volt accu laden", 'https://ownersmanual.audi.com/app/rdw/chapters/QlJFTVNFTg?language=nl_NL': "Kort en bondig\nWeergave en bediening\nStarten en rijden\nHulpsystemen\nInfotainment\nVerzorging en onderhoud\nZelf problemen verhelpen\nKlantinformatie\nPersonalisatie\nOpenen en sluiten\nLicht en zicht\nJuist en veilig zitten\nOpbergen en nuttige zaken\nWarm en koud\nRijden\nRijdynamiek\nHoogvoltsysteem\nRijden met aanhangwagen\nSystemen starten\nAandrijving\nRijstanden en schakelprogramma's\nRijden\nStart-stopsysteem\nRemmen\nParkeerrem\nBijzondere rijsituaties\nVeiligheidsaanwijzingen voor remmen\nInleiding\nInformatie over remmen\nAanwijzingen voor de bestuurder met betrekking tot het remsysteem", 'https://ownersmanual.audi.com/app/rdw/chapters/QlJFTVNGTFVFU1NJR0tFSVQ?language=nl_NL': 'Kort en bondig\nWeergave en bediening\nStarten en rijden\nHulpsystemen\nInfotainment\nVerzorging en onderhoud\nZelf problemen verhelpen\nKlantinformatie\nControleren en bijvullen\nWielen\nVerzorgen en schoonmaken\nBrandstof\nTanken\nSelective Catalytic Reduction (AdBlue/DEF)\nUitlaatgasreinigingssysteem\nRoetfilter\nMotorruimte\nMotorolie\nKoelsysteem\nRemvloeistof\nElektrische installatie\nAccu\nRuitensproeierinstallatie\nService-intervalindicatie\nSmart Service\nOnline Car Care\nVeiligheidsaanwijzingen over remvloeistof\nRemvloeistof controleren en laten verversen\nAanwijzingen voor de bestuurder voor het remsysteem', 'https://ownersmanual.audi.com/app/rdw/chapters/QU1QRUxJTkZPUk1BVElPTkVO?language=nl_NL': 'Kort en bondig\nWeergave en bediening\nStarten en rijden\nHulpsystemen\nInfotainment\nVerzorging en onderhoud\nZelf problemen verhelpen\nKlantinformatie\nAlgemene infor ...
