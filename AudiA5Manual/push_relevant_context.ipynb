# %%
import os
import glob
from dotenv import load_dotenv
from openai import OpenAI

# %%
from services.text_helpers import load_url_text_map

a5Manual = load_url_text_map()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 from services.text_helpers import load_url_text_map
#       2
# ----> 3 a5Manual = load_url_text_map()
#
# File c:\Learning\AI\Mike_LLM\AudiA5Manual\services\text_helpers.py:16, in load_url_text_map(raw_dir)
#      13     with json_file.open(encoding="utf-8") as f:
#      14         entry = json.load(f)
# ---> 16     url_text_map[entry["url"]] = entry["text"]
#      18 return url_text_map
#
# TypeError: list indices must be integers or slices, not str
